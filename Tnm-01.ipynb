# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(-4,4,100)
y=np.sin(x)*np.random.rand(100)
z=np.cos(x)+np.random.rand(100)*0.3
plt.plot(x,y)
plt.plot(x,z)
